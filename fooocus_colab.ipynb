# %%
import sys

# Uninstall potentially conflicting versions
# !pip uninstall -y rembg cupy numpy

# Install a compatible numpy version
# !pip install numpy==1.23.5

# Install cupy-cuda12x for Colab's typical environment
# !pip install cupy-cuda12x

# Install rembg which depends on cupy
# !pip install rembg

# Install pygit2 and run Fooocus as originally intended
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# WARNING: Skipping rembg as it is not installed.
# WARNING: Skipping cupy as it is not installed.
# Found existing installation: numpy 2.4.4
# Uninstalling numpy-2.4.4:
#   Successfully uninstalled numpy-2.4.4
# ...
#   Using cached numpy-1.23.5.tar.gz (10.7 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
